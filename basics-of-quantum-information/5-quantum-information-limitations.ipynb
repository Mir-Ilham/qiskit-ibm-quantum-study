# %% [markdown]
# # Limitations on Quantum Information

# %% [markdown]
# ## Irrelevance of global phases

# %% [markdown]
# Suppose that $|\psi\rangle$ and $|\phi\rangle$ are quantum state vectors satisfying
#
# $$
# |\phi\rangle = \alpha |\psi\rangle
# $$
#
# The states $|\psi\rangle$ and $|\phi\rangle$ are then said to **differ by a global phase**.
#
# This requires $|\alpha| = 1$ Equivalently, $\alpha = e^{i\theta}$ for some real number $\theta$.
#
# ---
#
# Imagine that two states that differ by a global phase are measured.
#
# If we start with the state $|\phi\rangle$, the probability to obtain any chosen outcome $a$ is
#
# $$
# |\langle a|\phi\rangle|^2
# =
# |\alpha \langle a|\psi\rangle|^2
# =
# |\alpha|^2 |\langle a|\psi\rangle|^2
# =
# |\langle a|\psi\rangle|^2
# $$
#
# or
#
# $$
# \|\Pi_a |\phi\rangle\|^2
# =
# \|\alpha \Pi_a |\psi\rangle\|^2
# =
# |\alpha|^2 \|\Pi_a |\psi\rangle\|^2
# =
# \|\Pi_a |\psi\rangle\|^2
# $$
#
# That is the same probability as if we started with the state $|\psi\rangle$.

# %% [markdown]
# Suppose we apply a unitary operation to two states that differ by a global phase:
#
# $$
# U|\phi\rangle
# =
# \alpha U|\psi\rangle
# =
# \alpha (U|\psi\rangle)
# $$
#
# They still differ by a global phase.
#
# Consequently, two quantum state vectors $|\psi\rangle$ and $|\phi\rangle$ that differ by a global phase are **completely indistinguishable** and are considered to be **equivalent**.

# %% [markdown]
# - The two states below differ by a global phase and thus equivalent

# %%
from qiskit.quantum_info import Statevector
from numpy import sqrt

ket1 = Statevector([1 / sqrt(2), -1 / sqrt(2)])
ket2 = Statevector([-1 / sqrt(2), 1 / sqrt(2)])

print(ket1.is_valid())
print(ket2.is_valid())
# Out:
# True
# True

# %% [markdown]
# ## No-cloning theorem

# %% [markdown]
# Let $X$ and $Y$ both have the classical state set $\{0, \dots, d-1\}, \quad \text{where } d \geq 2$.
#
# There does not exist a unitary operation $U$ on the pair $(X,Y)$ such that
#
# $$
# \forall |\psi\rangle :
# U(|\psi\rangle \otimes |0\rangle)
# =
# |\psi\rangle \otimes |\psi\rangle
# $$

# %% [markdown]
# ## Discriminating non-orthogonal states

# %% [markdown]
# - It is not possible to perfectly discriminate two non-orthogonal quantum states. Equivalently, if we can discriminate two quantum states perfectly, then they must be orthogonal.
